# %%
numbers = []

for i in range(5):
    element = int(input(f"Enter element {i+1}: "))
    numbers.append(element)

print("List created:", numbers)
# Out:
# Enter element 1:  10
# Enter element 2:  20
# Enter element 3:  30
# Enter element 4:  40
# Enter element 5:  50
# List created: [10, 20, 30, 40, 50]

# %%
numbers = [10, 20, 30, 40, 50]

print("Elements in the list are:")
for element in numbers:
    print(element)
# Out:
# Elements in the list are:
# 10
# 20
# 30
# 40
# 50

# %%
numbers = [10, 20, 30, 40, 50]

element = int(input("Enter an element to add: "))

numbers.append(element)

print("Updated List:", numbers)
# Out:
# Enter an element to add:  90
# Updated List: [10, 20, 30, 40, 50, 90]

# %%
numbers = [10, 20, 30, 40, 50]

index = int(input("Enter index: "))
element = int(input("Enter element: "))

numbers.insert(index, element)

print("Updated List:", numbers)
# Out:
# Enter index:  3
# Enter element:  44
# Updated List: [10, 20, 30, 44, 40, 50]

# %%
numbers = [10, 20, 30, 40, 50]

index = int(input("Enter index to remove: "))

numbers.pop(index)

# Remove first element
numbers.pop(0)

# Remove last element
numbers.pop()

print("Updated List:", numbers)
# Out:
# Enter index to remove:  3
# Updated List: [20, 30]

# %%
numbers = [10, 20, 30, 40, 50]

element = int(input("Enter element to remove: "))

if element in numbers:
    numbers.remove(element)
    print("Remaining Elements:", numbers)
else:
    print("Element not found in the list")
# Out:
# Enter element to remove:  40
# Remaining Elements: [10, 20, 30, 50]

# %%
numbers = [10, 20, 30, 40, 50]

print("Original List:", numbers)

del numbers

print("List deleted successfully")
# Out:
# Original List: [10, 20, 30, 40, 50]
# List deleted successfully
