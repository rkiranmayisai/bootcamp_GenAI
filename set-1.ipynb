# %%
numbers = [10, 20, 30, 40, 50]

total = sum(numbers)

print("List:", numbers)
print("Sum of all elements:", total)
# Out:
# List: [10, 20, 30, 40, 50]
# Sum of all elements: 150

# %%
numbers = [45, 12, 78, 3, 56, 89, 23]

largest = max(numbers)
smallest = min(numbers)

print("List:", numbers)
print("Largest number:", largest)
print("Smallest number:", smallest)
# Out:
# List: [45, 12, 78, 3, 56, 89, 23]
# Largest number: 89
# Smallest number: 3

# %%
numbers = [10, 15, 22, 37, 40, 55, 68, 71]

even_count = 0
odd_count = 0

for num in numbers:
    if num % 2 == 0:
        even_count += 1
    else:
        odd_count += 1

print("List:", numbers)
print("Even numbers count:", even_count)
print("Odd numbers count:", odd_count)
# Out:
# List: [10, 15, 22, 37, 40, 55, 68, 71]
# Even numbers count: 4
# Odd numbers count: 4

# %%
numbers = [10, 20, 30, 20, 40, 10, 50, 30]

unique_numbers = []

for num in numbers:
    if num not in unique_numbers:
        unique_numbers.append(num)

print("Original List:", numbers)
print("List after removing duplicates:", unique_numbers)
# Out:
# Original List: [10, 20, 30, 20, 40, 10, 50, 30]
# List after removing duplicates: [10, 20, 30, 40, 50]

# %%
numbers = [10, 20, 30, 40, 50]

reversed_list = []

for i in range(len(numbers) - 1, -1, -1):
    reversed_list.append(numbers[i])

print("Original List:", numbers)
print("Reversed List:", reversed_list)
# Out:
# Original List: [10, 20, 30, 40, 50]
# Reversed List: [50, 40, 30, 20, 10]
